# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm

# %%
#!pip install implicit
# Out:
# Collecting implicit
#   Downloading implicit-0.6.1-cp310-cp310-win_amd64.whl (633 kB)
#      -------------------------------------- 633.2/633.2 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=0.16 in o:\!p\!p00_ai_hack_ai\hack_ai_venv\lib\site-packages (from implicit) (1.8.1)
# Requirement already satisfied: numpy in o:\!p\!p00_ai_hack_ai\hack_ai_venv\lib\site-packages (from implicit) (1.23.1)
# Requirement already satisfied: tqdm>=4.27 in o:\!p\!p00_ai_hack_ai\hack_ai_venv\lib\site-packages (from implicit) (4.64.0)
# Requirement already satisfied: colorama in o:\!p\!p00_ai_hack_ai\hack_ai_venv\lib\site-packages (from tqdm>=4.27->implicit) (0.4.5)
# Installing collected packages: implicit
# Successfully installed implicit-0.6.1

# %%
#!pip install h5py
# Out:
# Collecting h5py
#   Using cached h5py-3.7.0-cp310-cp310-win_amd64.whl (2.6 MB)
# Requirement already satisfied: numpy>=1.14.5 in o:\!p\!p00_ai_hack_ai\hack_ai_venv\lib\site-packages (from h5py) (1.23.1)
# Installing collected packages: h5py
# Successfully installed h5py-3.7.0

# %%
#считывание данных
users = pd.read_csv('train/users.csv', sep=';', index_col=None, dtype={'age': str, 'chb': str, 'chit_type': str, 'gender': str})
items = pd.read_csv('train/items.csv', sep=';', index_col=None, dtype={'author': str, 'bbk': str, 'izd': str, 'sys_numb': str, 'title': str, 'year_izd': str})
train_transactions = pd.read_csv('train/train_transactions_extended.csv', sep=';', index_col=None, dtype={'chb': str, 'date_1': str, 'is_printed': str, 'is_real': str, 'source': str, 'sys_numb': str, 'type': str})

# %%
print(f"Кол-во пользователей: {len(train_transactions['chb'].unique())}")
print(f"Кол-во документов в истории пользователей: {len(train_transactions['sys_numb'].unique())}")
print(f"Общее кол-во документов: {len(items['sys_numb'].unique())}")
# Out:
# Кол-во пользователей: 16753
# Кол-во документов в истории пользователей: 194666
# Общее кол-во документов: 354355

# %%
#строго фиксируем кол-во пользователей и уникальных документов
n_users = len(train_transactions['chb'].unique())
n_items = len(items['sys_numb'].unique())

# %%
#т.к далее придётся работать с матрицами создадим словари, которые точно отображают индексы в chb/sys_numb и обратно
mapping_chb_index = {chb_number: index for index, chb_number in enumerate(train_transactions['chb'].unique())}
mapping_sys_numb_index = {sys_number: index for index, sys_number in enumerate(items['sys_numb'].unique())}

mapping_index_chb = {index: chb_number for index, chb_number in enumerate(train_transactions['chb'].unique())}
mapping_index_sys_numb = {index: sys_number for index, sys_number in enumerate(items['sys_numb'].unique())}

# %%
#в базовом решении будем не будем использовать дополнительные данные о взаимодействиях
train_transactions = train_transactions[['chb', 'sys_numb']]

# %%
from sklearn.model_selection import train_test_split

# делим данные на тренировочный и тестовый наборы
train_data, test_data = train_test_split(train_transactions, test_size=0.20)

# %%
# Не очень удачное разбиение на train и test, поскольку в выборке для тестирования присутствуют не все пользователи. 
# Это означает, что понять, насколько рекомендательна система качественно работает для данного сегмента не получится.

print(f"Кол-во уникальных пользователей: {len(train_transactions['chb'].unique())}")
print(f"Кол-во уникальных пользователей в выборке для обучения: {len(train_data['chb'].unique())}")
print(f"Кол-во уникальных пользователей в выборке для тестирования: {len(test_data['chb'].unique())}")
# Out:
# Кол-во уникальных пользователей: 16753
# Кол-во уникальных пользователей в выборке для обучения: 16675
# Кол-во уникальных пользователей в выборке для тестирования: 12379

# %%
# Имеем дело с разряженными матрицами с ними лучше работать в sparse формате

def df_to_sparse(df):
    row = []
    col = []
    data = []

    for line in df.itertuples():
        row.append(mapping_chb_index[line.chb])
        col.append(mapping_sys_numb_index[line.sys_numb])
        data.append(1)

    return csr_matrix((data, (row, col)))

# %%
# Имеем дело с разряженными матрицами с ними лучше работать в sparse формате

def df_to_sparse0(df):
    row = []
    col = []
    data = []

    for line in df.itertuples():
        row.append(mapping_chb_index[line.chb])
        cur_sys_numb = line.sys_numb
        col.append(mapping_sys_numb_index[line.sys_numb])
        data.append(1)

    return csr_matrix((data, (row, col)))

# %%
# получение sparse матрицы user-item для train/test
train_data_sparse = df_to_sparse(train_data)
test_data_sparse = df_to_sparse(test_data)

# %%
from implicit.als import AlternatingLeastSquares

#В качестве базового решения попробуем алгоритм ALS. Подробнее можно ознакомиться с ним здесь - https://github.com/benfred/implicit
model = AlternatingLeastSquares()
model.fit(train_data_sparse)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# Получим рекомендации для конкретного пользователя 
userid = 2233
ids, scores = model.recommend(userid, train_data_sparse[userid], N=20, filter_already_liked_items=True)

# %%
ids, scores
# Out:
# (array([201127, 164122,  87192, 223024, 108298,  85490, 262997, 272421,
#         253593, 259039, 276186, 214956, 247717, 189785, 155667,  20479,
#         251169, 206303, 126120, 336502]),
#  array([3.5023299e-05, 3.4865916e-05, 3.4673121e-05, 3.4142184e-05,
#         3.3430835e-05, 3.3094668e-05, 3.2136042e-05, 3.1513784e-05,
#         3.1461524e-05, 3.1351825e-05, 3.1100913e-05, 3.1026342e-05,
#         3.1010091e-05, 3.0926440e-05, 3.0921947e-05, 3.0899020e-05,
#         3.0893709e-05, 3.0893709e-05, 3.0889249e-05, 3.0878971e-05],
#        dtype=float32))

# %%
tsys_numb = []
for id in ids:
    tsys_numb.append(mapping_index_sys_numb[id])
    print(mapping_index_sys_numb[id])
# Out:
# RSL01009646136
# RSL01004125780
# RSL01002679335
# RSL01007046521
# RSL01007830458
# RSL01002463969
# RSL01010448074
# RSL01002835455
# RSL01002835160
# RSL01010677200
# RSL01008959412
# RSL01010323553
# RSL01010544270
# RSL01010313840
# RSL01002792974
# RSL01002993589
# RSL01010528416
# RSL01010185166
# RSL01005462641
# RSL01002958891

# %%
tuserid = mapping_index_chb[userid]

# %%
tids = train_transactions[train_transactions['chb']==tuserid]

# %%
# Отобразим рекомендации в DataFrame
top20recom_df = pd.DataFrame({"sys_numb": [mapping_index_sys_numb[id] for id in ids], "score": scores, "already_liked": np.in1d(ids, train_data_sparse[userid].indices)})

# %%
def get_recom(userid):
    ids, scores = model.recommend(userid, train_data_sparse[userid], N=20, filter_already_liked_items=True)
    top20recom_df = pd.DataFrame({"sys_numb": [mapping_index_sys_numb[id] for id in ids], "score": scores, "already_liked": np.in1d(ids, train_data_sparse[userid].indices)})
    return top20recom_df['sys_numb'].values

# %%
#подбор рекомендаций для всех пользователей из train

all_rec = []

for userid in tqdm(range(train_data_sparse.shape[0])):
    user_chb = mapping_index_chb[userid]
    user_rec = get_recom(userid)
    for rec in user_rec:
        all_rec.append([user_chb, rec])
# Out:
#   0%|          | 0/16753 [00:00<?, ?it/s]

# %%
# DataFrame для отправки решения с рекомендациями
solution = pd.DataFrame(all_rec, columns=["chb", "sys_numb"])

# %%
# Формирование csv файла для отправки на платформу
solution.to_csv("solution.csv", index=False, sep=';')

# %% [markdown]
# ## Метрика

# %%
df_solution = solution
df_grd = test_data

# %%
#считаем recall, precision, f1_score

def metric(df_solution, df_grd):
    pred = set(df_solution['chb'] + '_' + df_solution['sys_numb'].values)
    true = set(df_grd['chb'] + '_' + df_grd['sys_numb'].values)
    recall = len(pred.intersection(true)) / len(true)
    precision = len(pred.intersection(true)) / (20 * len(df_grd['chb'].unique()))
    f1_score = 2 * (precision * recall) / (precision + recall)
    print(f"Recall: {round(recall, 5)}")
    print(f"Precision: {round(precision, 5)}")
    print(f"F1-score: {round(f1_score, 5)}")

# %%
# оценка базового решения

metric(df_solution, df_grd)
# Out:
# Recall: 0.01527
# Precision: 0.00309
# F1-score: 0.00514

# %%
# подадим ответы в качестве рекомендаций
metric(df_grd, df_grd)
# Out:
# Recall: 1.0
# Precision: 0.20222
# F1-score: 0.33641

# %%
# создадим случайные рекомендации 
random_solution = []
for chb in tqdm(set(df_grd['chb'].values)):
    for sys in items['sys_numb'].sample(20).values:
        random_solution.append([chb, sys])
# Out:
#   0%|          | 0/12406 [00:00<?, ?it/s]

# %%
# оценка подхода со случайными рекомендациями
metric(pd.DataFrame(random_solution, columns=['chb', 'sys_numb']), df_grd)
# Out:
# Recall: 4e-05
# Precision: 1e-05
# F1-score: 1e-05

# %% [markdown]
# ### Занимаемся BM25

# %%
# !pip install rank_bm25
# Out:
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: numpy in o:\!p\!p00_ai_hack_ai\hack_ai_venv\lib\site-packages (from rank_bm25) (1.23.1)
# Installing collected packages: rank_bm25
# Successfully installed rank_bm25-0.2.2

# %%
from rank_bm25 import BM25Okapi

corpus = [
    "Привет моя дорогая"
    "Hello there good man!",
    "It is quite windy in London",
    "How is the weather today?"
]

tokenized_corpus = [doc.split(" ") for doc in corpus]

bm25 = BM25Okapi(tokenized_corpus)

# %%
query = "Привет"
tokenized_query = query.split(" ")

doc_scores = bm25.get_scores(tokenized_query)

# %%
doc_scores
# Out:
# array([0.49765247, 0.        , 0.        ])

# %%
items['title']
# Out:
# 0         Судебное следствие в уголовном процессе России...
# 1         Уральское казачество и его роль в системе росс...
# 2                                               отсутствует
# 3                                               отсутствует
# 4         "Я пишу как эхо другого.." : Очерки интеллекту...
#                                 ...
# 354350                 Канада. География, экономика, право
# 354351    Изменения географических названий стран СНГ : ...
# 354352    К информационному обществу: использование инфо...
# 354353    Один раз на всю жизнь : возможен ли брак по лю...
# 354354    Works / Min. of culture a. monuments protectio...
# Name: title, Length: 354355, dtype: object

# %%
corpus = items['title'].tolist()

# %%
for i in range(len(corpus)):
    corpus[i] = corpus[i].strip()
    corpus[i] = corpus[i].lower()
    corpus[i] = corpus[i].replace(':','')
    corpus[i] = corpus[i].replace('/','')
    
tokenized_corpus = [doc.split() for doc in corpus]

# %%
tokenized_corpus
# Out:
# [['судебное',
#   'следствие',
#   'в',
#   'уголовном',
#   'процессе',
#   'россии',
#   'монография'],
#  ['уральское',
#   'казачество',
#   'и',
#   'его',
#   'роль',
#   'в',
#   'системе',
#   'российской',
#   'государственности',
#   '(середина',
#   'xvii',
#   '-',
#   'xix',
#   'вв.)',
#   'диссертация',
#   '..',
#   'доктора',
#   'исторических',
#   'наук',
#   '07.00.02'],
#  ['отсутствует'],
#  ['отсутствует'],
#  ['"я',
#   'пишу',
#   'как',
#   'эхо',
#   'другого.."',
#   'очерки',
#   'интеллектуал.',
#   'биографии',
#   'густава',
#   'шпета'],
#  ['использование',
#   'дробных',
#   'физических',
#   'нагрузок',
#   'в',
#   'статодинамическом',
#   'режиме',
#   'в',
#   'комплексной',
#   'реабилитации',
#   'больных',
#   'ревматоидным',
#   'артритом',
#   'диссертация',
#   '..',
#   'кандидата',
#   'медицинских',
#   'наук',
#   '14.00.39'],
#  ['отсутствует'],
#  ['очерк', 'психологии', 'полиморфной', 'индивидуальности', 'монография'],
#  ['факторы,',
#   'определяющие',
#   'приверженность',
#   'к',
#   'лечению',
#   'больных',
#   'ишемической',
#   'болезнью',
#   'сердца',
#   'диссертация',
#   '..',
#   'кандидата',
#   'медицинских',
#   'наук',
#   '14.00.05'],
#  ['отсутствует'],
#  ['становление',
#   'субъектности',
#   'студента',
#   'с',
#   'использованием',
#   'интерактивных',
#   'образовательных',
#   'технологий',
#   'в',
#   'вузе',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.08'],
#  ['государственный',
#   'контракт',
#   'как',
#   'особая',
#   'модель',
#   'гражданско-правового',
#   'договора',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.03'],
#  ['теоретические',
#   'и',
#   'технологические',
#   'основы',
#   'диагностики',
#   'организационных',
#   'конфликтов',
#   'диссертация',
#   '..',
#   'кандидата',
#   'социологических',
#   'наук',
#   '22.00.08'],
#  ['русский',
#   'язык',
#   'в',
#   'школе',
#   '=',
#   'russian',
#   'language',
#   'at',
#   'school',
#   'научно-методический',
#   'журнал',
#   'выпуски',
#   'за',
#   '2022',
#   'год',
#   '2022,',
#   'т.',
#   '83,',
#   '№',
#   '1'],
#  ['от',
#   'звука',
#   'к',
#   'тексту',
#   'человек',
#   'и',
#   'язык.',
#   'язык',
#   'разгадки',
#   'и',
#   'загадки.',
#   'язык',
#   'и',
#   'текст'],
#  ['поэтика', 'сказа'],
#  ['совершенствование',
#   'механизма',
#   'государственной',
#   'поддержки',
#   'малого',
#   'предпринимательства',
#   'на',
#   'основе',
#   'разработки',
#   'инструментария',
#   'оценки',
#   'ее',
#   'результативности',
#   'диссертация',
#   '..',
#   'кандидата',
#   'экономических',
#   'наук',
#   '08.00.05'],
#  ['стохастические',
#   'и',
#   'распределённые',
#   'методы',
#   'с',
#   'компрессией',
#   'градиентов',
#   'и',
#   'локальными',
#   'шагами',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'физико-математических',
#   'наук',
#   '05.13.18'],
#  ['пушкин',
#   'в',
#   'жизни',
#   'систематический',
#   'свод',
#   'подлинных',
#   'свидетельств',
#   'современников',
#   'с',
#   'иллюстрациями',
#   'на',
#   'отдельных',
#   'листах',
#   'в.',
#   'вересаев',
#   'т.',
#   '2'],
#  ['семантика',
#   'и',
#   'дейктические',
#   'функции',
#   'личных',
#   'местоимений',
#   'в',
#   'современном',
#   'английском',
#   'языке',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук'],
#  ['сравнительная',
#   'оценка',
#   'линий',
#   'и',
#   'семейств',
#   'лошадей',
#   'чистокровной',
#   'арабской',
#   'породы',
#   'по',
#   'промерам',
#   'статей',
#   'тела',
#   'и',
#   'работоспособности',
#   'диссертация',
#   '..',
#   'кандидата',
#   'сельскохозяйственных',
#   'наук',
#   '06.02.01'],
#  ['роль',
#   'моноаминов',
#   'в',
#   'регуляции',
#   'функциональной',
#   'активности',
#   'орексинергических',
#   'нейронов',
#   'гипоталамуса',
#   'на',
#   'разных',
#   'этапах',
#   'онтогенеза',
#   'диссертация',
#   '..',
#   'кандидата',
#   'биологических',
#   'наук',
#   '03.03.01,',
#   '03.03.04'],
#  ['борьба',
#   'с',
#   'преступностью',
#   'и',
#   'обеспечение',
#   'общественного',
#   'порядка',
#   'в',
#   'послевоенном',
#   'ссср',
#   '1945-1953',
#   'гг.',
#   'диссертация',
#   '..',
#   'кандидата',
#   'исторических',
#   'наук',
#   '07.00.02'],
#  ['пушкинская',
#   'традиция',
#   'в',
#   'процессе',
#   'становления',
#   'и',
#   'развития',
#   'жанра',
#   'тургеневского',
#   'романа',
#   '1850-х',
#   '-',
#   'начала',
#   '1860-х',
#   'годов',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.01.01'],
#  ['об',
#   'эффектах',
#   'магнитных',
#   'примесей',
#   'и',
#   'взаимодействия',
#   'на',
#   'свойства',
#   'неупорядоченных',
#   'металлов',
#   'диссертация',
#   '..',
#   'кандидата',
#   'физико-математических',
#   'наук',
#   '01.04.02'],
#  ['духовная',
#   'музыка',
#   'м.м.',
#   'ипполитова-иванова',
#   'и',
#   'русская',
#   'певческая',
#   'традиция',
#   'диссертация',
#   '..',
#   'кандидата',
#   'искусствоведения',
#   '17.00.02'],
#  ['проектирование',
#   'и',
#   'реализация',
#   'воспитательной',
#   'системы',
#   'детского',
#   'оздоровительного',
#   'лагеря',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.01'],
#  ['формирование',
#   'профессиональной',
#   'компетентности',
#   'студентов',
#   'среднего',
#   'профобразования',
#   'при',
#   'интегрированном',
#   'изучении',
#   'дискретной',
#   'математики',
#   'и',
#   'информатики',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.08'],
#  ['воспоминания', 'о', 'михаиле', 'булгакове'],
#  ['отсутствует'],
#  ['отсутствует'],
#  ['операторный',
#   'подход',
#   'к',
#   'построению',
#   'комплексных',
#   'и',
#   'отражающихся',
#   'случайных',
#   'процессов',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'физико-математических',
#   'наук',
#   '01.01.05'],
#  ['языковая',
#   'специфика',
#   '"миссии',
#   'организации"',
#   'в',
#   'английском',
#   'виртуальном',
#   'корпоративном',
#   'дискурсе',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.02.04'],
#  ['отсутствует'],
#  ['дисциплинарная',
#   'ответственность',
#   'за',
#   'нарушения',
#   'законодательства',
#   'о',
#   'противодействии',
#   'коррупции',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.14'],
#  ['разработка',
#   'системы',
#   'мониторинга',
#   'и',
#   'нейтрализации',
#   'выхлопных',
#   'газов',
#   'двигателей',
#   'внутреннего',
#   'сгорания',
#   'в',
#   'местах',
#   'их',
#   'настройки,',
#   'обкатки',
#   'и',
#   'регулировки',
#   'диссертация',
#   '..',
#   'кандидата',
#   'технических',
#   'наук',
#   '05.11.13'],
#  ['юрисдикция',
#   'международного',
#   'уголовного',
#   'суда',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.10'],
#  ['правовые',
#   'основы',
#   'и',
#   'практика',
#   'выборов',
#   'в',
#   'государственную',
#   'думу',
#   'российской',
#   'империи',
#   'на',
#   'региональном',
#   'уровне',
#   'на',
#   'примере',
#   'нижегородской',
#   'губернии',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.01'],
#  ['современная',
#   'инвестиционная',
#   'и',
#   'инновационная',
#   'политика',
#   'государства'],
#  ['злоупотребление',
#   'правом',
#   'на',
#   'иск',
#   'в',
#   'гражданском',
#   'процессе',
#   'германии',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.15'],
#  ['горное',
#   'право',
#   'учебное',
#   'пособие',
#   'для',
#   'студентов',
#   'высших',
#   'учебных',
#   'заведений,',
#   'обучающихся',
#   'по',
#   'направлению',
#   '"юриспруденция"',
#   '(030900-62-бакалавр)'],
#  ['представления',
#   'об',
#   'образовании',
#   'и',
#   'учености',
#   'в',
#   'корейской',
#   'литературе',
#   'периода',
#   'чосон',
#   '1392-1910',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.01.03'],
#  ['отсутствует'],
#  ['библиотека',
#   'в',
#   'контексте',
#   'истории',
#   'материалы',
#   '4-й',
#   'междунар.',
#   'науч.',
#   'конф.,',
#   'москва,',
#   '24-26',
#   'окт.',
#   '2001',
#   'г.'],
#  ['организационно-педагогическое',
#   'обеспечение',
#   'брендинга',
#   'образовательных',
#   'услуг',
#   'современного',
#   'вуза',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.08'],
#  ['творчество',
#   'жана-батиста',
#   'ванмура',
#   '(1671-1737)',
#   'и',
#   'проблема',
#   'ориентализма',
#   'в',
#   'западноевропейской',
#   'живописи',
#   'xviii',
#   'века',
#   'диссертация',
#   '..',
#   'кандидата',
#   'искусствоведения',
#   '17.00.04'],
#  ['отсутствует'],
#  ['сравнительная',
#   'политология',
#   'учебник',
#   'для',
#   'студентов',
#   'вузов,',
#   'обучающихся',
#   'по',
#   'направлениям',
#   'подготовки',
#   '(специальностям)',
#   "''''международные",
#   "отношения''''",
#   'и',
#   "''''зарубежное",
#   "регионоведение''''"],
#  ['исследование',
#   'радиационной',
#   'стойкости',
#   'высокоомного',
#   'арсенида',
#   'галлия',
#   'для',
#   'применения',
#   'в',
#   'детекторах',
#   'элементарных',
#   'частиц',
#   'на',
#   'будущих',
#   'лептонных',
#   'коллайдерах',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'физико-математических',
#   'наук',
#   '01.04.01'],
#  ['детская',
#   'повседневность',
#   'советской',
#   'россии',
#   '1920-х',
#   'гг.',
#   'на',
#   'материалах',
#   'курганского',
#   'и',
#   'шадринского',
#   'округов',
#   'диссертация',
#   '..',
#   'кандидата',
#   'исторических',
#   'наук',
#   '07.00.02'],
#  ['эвфемия',
#   'в',
#   'общественно-политической',
#   'лексике',
#   'на',
#   'материале',
#   'современного',
#   'немецкого,',
#   'русского',
#   'и',
#   'башкирского',
#   'языков',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.02.20'],
#  ['традиции',
#   'поэтики',
#   'и.с.',
#   'тургенева',
#   'в',
#   'русской',
#   'литературе',
#   'xx',
#   'в.',
#   '(б.к.',
#   'зайцев,',
#   'к.г.',
#   'паустовский,',
#   'ю.п.',
#   'казаков)',
#   'диссертация',
#   '..',
#   'доктора',
#   'филологических',
#   'наук',
#   '10.01.01'],
#  ['отсутствует'],
#  ['от',
#   'классицизма',
#   'к',
#   'сентиментализму',
#   'учеб.-метод.',
#   'пособие',
#   'для',
#   'студентов',
#   'филол.',
#   'фак.',
#   'вузов'],
#  ['избранные', 'работы', 'по', 'языкознанию'],
#  ['повышение',
#   'энергетической',
#   'эффективности',
#   'зданий,',
#   'эксплуатируемых',
#   'в',
#   'условиях',
#   'переменного',
#   'теплового',
#   'режима',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'технических',
#   'наук',
#   '05.23.03'],
#  ['эстетические',
#   'воззрения',
#   'сигизмунда',
#   'кржижановского',
#   'от',
#   'шекспироведения',
#   'к',
#   'философии',
#   'искусства',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.01.01'],
#  ['доказательства',
#   'при',
#   'рассмотрении',
#   'дел',
#   'o',
#   'защите',
#   'прав',
#   'потребителей',
#   'учебное',
#   'пособие'],
#  ['полномочный',
#   'представитель',
#   'президента',
#   'российской',
#   'федерации',
#   'в',
#   'федеральном',
#   'округе',
#   'правовой',
#   'статус',
#   'и',
#   'функции',
#   'на',
#   'примере',
#   'центрального',
#   'федерального',
#   'округа',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.02'],
#  ['отсутствует'],
#  ['отсутствует'],
#  ['лингвистическая',
#   'репрезентация',
#   'концепта',
#   'гражданственность',
#   'в',
#   'творчестве',
#   'е.а.',
#   'евтушенко',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.02.01'],
#  ['динамика',
#   'и',
#   'пространственное',
#   'распределение',
#   'солнечных',
#   'космических',
#   'лучей',
#   'в',
#   'гелиосфере',
#   'автореферат',
#   'дис..',
#   'доктора',
#   'физико-математических',
#   'наук',
#   '01.03.03'],
#  ['формирование',
#   'инженерной',
#   'компетентности',
#   'курсантов',
#   'военных',
#   'инженерных',
#   'вузов',
#   'при',
#   'интеграции',
#   'общетехнических',
#   'и',
#   'профессиональных',
#   'дисциплин',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.02'],
#  ['отсутствует'],
#  ['разработка',
#   'огнезащитного',
#   'состава',
#   'для',
#   'создания',
#   'полимерного',
#   'покрытия',
#   'древесных',
#   'материалов',
#   'диссертация',
#   '..',
#   'кандидата',
#   'технических',
#   'наук',
#   '05.17.06'],
#  ['судебная',
#   'власть',
#   'на',
#   'защите',
#   'конституционного',
#   'права',
#   'граждан',
#   'на',
#   'свободу',
#   'и',
#   'личную',
#   'неприкосновенность',
#   'в',
#   'уголовном',
#   'процессе',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.09'],
#  ['тенденции',
#   'российской',
#   'уголовно-правовой',
#   'политики',
#   'постсоветского',
#   'периода',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.08'],
#  ['повесть-сказка',
#   'в',
#   'русской',
#   'детской',
#   'литературе',
#   '60-х',
#   'годов',
#   'xx',
#   'века',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.01.01'],
#  ['гендерная',
#   'социализация',
#   'в',
#   'процессе',
#   'профессионального',
#   'самоопределения',
#   'старших',
#   'школьников',
#   'диссертация',
#   '..',
#   'кандидата',
#   'психологических',
#   'наук',
#   '19.00.07'],
#  ['инновационная',
#   'экономика',
#   'и',
#   'современный',
#   'менеджмент',
#   'журнал',
#   'выпуски',
#   'за',
#   '2022',
#   'год',
#   '2022,',
#   '№',
#   '1',
#   '(37)'],
#  ['основы',
#   'нашей',
#   'непримиримости',
#   '(речь,',
#   'произнес.',
#   'на',
#   'собр.',
#   'в',
#   '"день',
#   'непримиримости",',
#   '7',
#   'нояб.',
#   '1947',
#   'г.',
#   'в',
#   'рус.',
#   'эмигрант.',
#   'лагере',
#   'шлейсгейм',
#   'близ',
#   'мюнхена)'],
#  ['римское', 'право', 'учебник'],
#  ['мода',
#   'как',
#   'социокультурный',
#   'фактор',
#   'функционирования',
#   'отечественной',
#   'индустрии',
#   'модной',
#   'одежды',
#   'на',
#   'примере',
#   'г.',
#   'москвы',
#   'диссертация',
#   '..',
#   'кандидата',
#   'социологических',
#   'наук',
#   '22.00.06'],
#  ['отсутствует'],
#  ['совершенствование',
#   'забуривания',
#   'новых',
#   'направлений',
#   'в',
#   'открытом',
#   'стволе',
#   'скважины',
#   'с',
#   'искусственного',
#   'забоя',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'технических',
#   'наук',
#   '25.00.14'],
#  ['современный',
#   'межкультурный',
#   'диалог',
#   'в',
#   'контексте',
#   'сетевых',
#   '(информационных)',
#   'взаимодействий',
#   'образовательного',
#   'пространства',
#   'снг',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'философских',
#   'наук',
#   '24.00.01'],
#  ['старославянский',
#   'язык,',
#   'древнерусский',
#   'язык',
#   'и',
#   'историческая',
#   'грамматика',
#   'русского',
#   'языка',
#   'опыт',
#   'сопоставительного',
#   'изучения',
#   'учебно-методическое',
#   'пособие'],
#  ['прекращение',
#   'уголовного',
#   'дела',
#   'в',
#   'связи',
#   'с',
#   'примирением',
#   'сторон',
#   'в',
#   'стадии',
#   'предварительного',
#   'расследования',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.09'],
#  ['в', 'окопах', '"холодной', 'войны"'],
#  ['совершенствование',
#   'управления',
#   'экономической',
#   'устойчивостью',
#   'развития',
#   'корпораций',
#   'тэк',
#   'на',
#   'примере',
#   'ао',
#   '«суэк-кузбасс»',
#   'диссертация',
#   '..',
#   'кандидата',
#   'экономических',
#   'наук',
#   '08.00.05'],
#  ['осада',
#   'и',
#   'сдача',
#   'крепости',
#   'п.-артур',
#   'мои',
#   'впечатления',
#   'с',
#   '2-мя',
#   'прил.'],
#  ['ценностно-коммуникационная',
#   'сущность',
#   'профессиональной',
#   'субкультуры',
#   'специалистов',
#   'библиотечного',
#   'социального',
#   'института',
#   'диссертация',
#   '..',
#   'доктора',
#   'педагогических',
#   'наук',
#   '05.25.03'],
#  ['император',
#   'александр',
#   'iii',
#   'ист.-полит.',
#   'чтение',
#   'в',
#   'ист.',
#   'музее',
#   'в',
#   'москве,',
#   '20',
#   'марта',
#   '1907',
#   'г.'],
#  ['иностранцы',
#   'в',
#   'москве',
#   'на',
#   'рубеже',
#   'xix',
#   '-',
#   'xx',
#   'вв.',
#   'диссертация',
#   '..',
#   'кандидата',
#   'исторических',
#   'наук',
#   '07.00.02'],
#  ['собрание',
#   'передовых',
#   'статей',
#   'московских',
#   'ведомостей',
#   'м.',
#   'н.',
#   'катков',
#   '..',
#   '1871',
#   'год'],
#  ['познавательная',
#   'деятельность',
#   'при',
#   'производстве',
#   'по',
#   'уголовным',
#   'делам',
#   'с',
#   'участием',
#   'присяжных',
#   'заседателей',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.09'],
#  ['девятисотлетие',
#   'православия',
#   'на',
#   'волыни.',
#   '992-1892',
#   'г.',
#   'ч.',
#   '1-2'],
#  ['отсутствует'],
#  ['персональные',
#   'данные',
#   'в',
#   'системе',
#   'информации',
#   'ограниченного',
#   'доступа',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.13'],
#  ['отсутствует'],
#  ['эффективность',
#   'и',
#   'безопасность',
#   'торакоскопической',
#   'лобэктомии',
#   'при',
#   'злокачественных',
#   'опухолях',
#   'легких',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'медицинских',
#   'наук',
#   '14.01.12',
#   '14.01.17'],
#  ['методы',
#   'и',
#   'алгоритмы',
#   'анизотропийного',
#   'управления',
#   'линейными',
#   'дескрипторными',
#   'и',
#   'параметрически',
#   'неопределенными',
#   'системами',
#   'автореферат',
#   'дис..',
#   'доктора',
#   'физико-математических',
#   'наук',
#   '05.13.01'],
#  ['юридическое',
#   'делегирование',
#   'теория,',
#   'практика,',
#   'техника',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.01'],
#  ['беспризорные'],
#  ['совершенствование',
#   'психолого-педагогической',
#   'подготовки',
#   'учителя',
#   'в',
#   'условиях',
#   'практико-ориентированного',
#   'образовательного',
#   'процесса',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.01'],
#  ['эмоциональный',
#   'интеллект',
#   'будущего',
#   'педагога',
#   'акмеологическая',
#   'диагностика',
#   'и',
#   'методы',
#   'развития'],
#  ['руководство',
#   'для',
#   'преподавания',
#   'артиллерии',
#   'в',
#   'морском',
#   'училище'],
#  ['педагогические',
#   'основы',
#   'развития',
#   'национальных',
#   'традиций',
#   'хореографии',
#   'китая',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.01'],
#  ['договор',
#   'купли-продажи',
#   'недвижимости',
#   'общие',
#   'положения',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.03'],
#  ['отсутствует'],
#  ['договор',
#   'аутсорсинга',
#   'в',
#   'гражданском',
#   'праве',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.03'],
#  ['физические',
#   'основы',
#   'контактных',
#   'процессов',
#   'при',
#   'прерывистом',
#   'резании',
#   'монография'],
#  ['концептуальные',
#   'основы',
#   'развивающего',
#   'иноязычного',
#   'образования',
#   'в',
#   'начальной',
#   'школе',
#   'монография'],
#  ['численные',
#   'методы',
#   'решения',
#   'задач',
#   'выпуклой',
#   'оптимизации',
#   'больших',
#   'размеров,',
#   'имеющих',
#   'специальную',
#   'структуру',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'физико-математических',
#   'наук',
#   '05.13.18'],
#  ['пришельцы', 'рядом', 'альм.', 'науч.', 'фантаст.'],
#  ['самореализация',
#   'человека',
#   'в',
#   'политике',
#   'диссертация',
#   '..',
#   'доктора',
#   'философских',
#   'наук',
#   '09.00.10'],
#  ['влияние',
#   'гибридных',
#   'механизмов',
#   'координации',
#   'на',
#   'экономическую',
#   'модернизацию',
#   'сообществ',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'экономических',
#   'наук',
#   '08.00.01'],
#  ['отсутствует'],
#  ['отсутствует'],
#  ['как',
#   'воюет',
#   'россия',
#   'совет.',
#   'воен.',
#   'доктрина',
#   'пер.',
#   'с',
#   'англ.',
#   'вып.',
#   '1-4',
#   'реймонд',
#   'гартхофф',
#   'вып.',
#   '1'],
#  ['электронная',
#   'обучающая',
#   'среда',
#   'moodle',
#   'как',
#   'средство',
#   'организации',
#   'асинхронной',
#   'самостоятельной',
#   'работы',
#   'студентов',
#   'вуза',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.01'],
#  ['античная',
#   'цивилизация',
#   'и',
#   'варвары',
#   'северного',
#   'причерноморья',
#   'в',
#   'условиях',
#   'этнических',
#   'миграций',
#   'диссертация',
#   '..',
#   'доктора',
#   'исторических',
#   'наук',
#   '07.00.03'],
#  ['внутрисердечная',
#   'эхокардиография',
#   'в',
#   'кардиохирургии',
#   'и',
#   'интервенционной',
#   'кардиологии',
#   'диссертация',
#   '..',
#   'кандидата',
#   'медицинских',
#   'наук',
#   '14.00.44'],
#  ['этимологические',
#   'тайны',
#   'русской',
#   'орфографии',
#   'слов.-справ.',
#   'ок.',
#   '6000',
#   'слов',
#   'учеб.',
#   'пособие',
#   'для',
#   'студентов',
#   'вузов,',
#   'обучающихся',
#   'по',
#   'направлению',
#   '520300',
#   'и',
#   'специальности',
#   '021700',
#   '-',
#   '"филология"'],
#  ['искусство',
#   'германии',
#   'и',
#   'австрии',
#   'в',
#   '"именах"',
#   'и',
#   'понятиях',
#   'монография'],
#  ['отсутствует'],
#  ['отсутствует'],
#  ['отсутствует'],
#  ['проблема',
#   'текста',
#   'в',
#   'философии',
#   'культуры',
#   'xx',
#   'века',
#   'диссертация',
#   '..',
#   'кандидата',
#   'философских',
#   'наук',
#   '09.00.13'],
#  ['собрание',
#   'постановлений',
#   'правительства',
#   'союза',
#   'советских',
#   'социалистических',
#   'республик',
#   '…',
#   'издание',
#   'управления',
#   'делами',
#   'совета',
#   'министров',
#   'ссср',
#   '1921,',
#   '№',
#   '1-80'],
#  ['письмо', 'дорошевичу,', 'власу', 'михайловичу', 'рукопись'],
#  ['оптимизация',
#   'оказания',
#   'медицинской',
#   'помощи',
#   'детям',
#   'с',
#   'неонатальными',
#   'инфекциями',
#   'автореферат',
#   'дис..',
#   'доктора',
#   'медицинских',
#   'наук',
#   '14.01.08,',
#   '14.02.03'],
#  ['экспериментально-опытное',
#   'обучение',
#   'английскому',
#   'языку',
#   'на',
#   'начальном',
#   'этапе',
#   'в',
#   'средней',
#   'школе',
#   'вводный',
#   'курс',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.02'],
#  ['неписанный', 'кодекс', 'везунчика.', 'как', 'стать', 'баловнем', 'судьбы'],
#  ['отсутствует'],
#  ['правотворчество', 'в', 'ссср'],
#  ['факторы',
#   'формирования',
#   'мотивации',
#   'учебной',
#   'деятельности',
#   'умственно',
#   'отсталых',
#   'младших',
#   'школьников',
#   'диссертация',
#   '..',
#   'кандидата',
#   'психологических',
#   'наук',
#   '19.00.10'],
#  ['представления',
#   'о',
#   'родительстве',
#   'у',
#   'детей',
#   'дошкольного,',
#   'младшего',
#   'школьного',
#   'и',
#   'подросткового',
#   'возраста',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'психологических',
#   'наук',
#   '19.00.13'],
#  ['воспитание',
#   'дисциплинированности',
#   'у',
#   'курсантов',
#   'военно-учебных',
#   'заведений',
#   'вооруженных',
#   'сил',
#   'республики',
#   'казахстан',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.08'],
#  ['отсутствует'],
#  ['москва',
#   'история,',
#   'архитектура,',
#   'памятники,',
#   'музеи,',
#   'прогулки,',
#   'москва',
#   'для',
#   'детей,',
#   'рестораны',
#   'и',
#   'клубы',
#   'путеводитель'],
#  ['отсутствует'],
#  ['отсутствует'],
#  ['отсутствует'],
#  ['патоморфологический,',
#   'иммуногистохимический',
#   'и',
#   'цитологический',
#   'анализ',
#   'красного',
#   'плоского',
#   'лишая',
#   'слизистой',
#   'оболочки',
#   'полости',
#   'рта',
#   'диссертация',
#   '..',
#   'кандидата',
#   'медицинских',
#   'наук',
#   '14.03.02'],
#  ['отсутствует'],
#  ['активная',
#   'спектроскопическая',
#   'диагностика',
#   'термоядерной',
#   'плазмы',
#   'анализ',
#   'эффективности',
#   'для',
#   'итэр',
#   'и',
#   'исследование',
#   'ионной',
#   'компоненты',
#   'плазмы',
#   'токамака',
#   'т-10',
#   'диссертация',
#   '..',
#   'кандидата',
#   'физико-математических',
#   'наук',
#   '01.04.08'],
#  ['проблемы',
#   'квалификации',
#   'преступлений',
#   'по',
#   'субъективным',
#   'признакам',
#   'монография'],
#  ['адресатность',
#   'в',
#   'политическом',
#   'дискурсе',
#   'ценности,',
#   'стратегии,',
#   'способы',
#   'выражения',
#   'диссертация',
#   '..',
#   'доктора',
#   'филологических',
#   'наук',
#   '10.02.19'],
#  ['совершенствование',
#   'конструкторско-технологической',
#   'подготовки',
#   'производства',
#   'на',
#   'основе',
#   'компьютерных',
#   'баз',
#   'знаний',
#   'и',
#   'реинжиниринга',
#   'технических',
#   'процессов',
#   'на',
#   'примере',
#   'оао',
#   '"сафоновский',
#   'электромашиностроительный',
#   'завод"',
#   'диссертация',
#   '..',
#   'кандидата',
#   'технических',
#   'наук',
#   '05.13.07'],
#  ['технико-криминалистическое',
#   'обеспечение',
#   'раскрытия',
#   'преступлений',
#   'по',
#   'горячим',
#   'следам',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.09'],
#  ['полное',
#   'собрание',
#   'сочинений',
#   'а.ф.',
#   'писемского',
#   'т.',
#   '9.',
#   'часть',
#   'первая,',
#   'вторая',
#   'и',
#   'третья.',
#   'взбаламученное',
#   'море',
#   'роман',
#   'в',
#   'шести',
#   'частях'],
#  ['философские',
#   'основания',
#   'искусственного',
#   'интеллекта',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'философских',
#   'наук',
#   '09.00.01'],
#  ['институт',
#   'репродуктивных',
#   'прав',
#   'человека',
#   'в',
#   'российской',
#   'федерации',
#   'конституционно-правовое',
#   'исследование',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.02'],
#  ['правовая',
#   'помощь',
#   'участникам',
#   'уголовного',
#   'судопроизводства',
#   'теоретические',
#   'и',
#   'правовые',
#   'основы,',
#   'перспективы',
#   'совершенствования',
#   'диссертация',
#   '..',
#   'доктора',
#   'юридических',
#   'наук',
#   '12.00.09'],
#  ['развитие',
#   'логистических',
#   'систем',
#   'распределения',
#   'на',
#   'основе',
#   'активизации',
#   'транзитного',
#   'потенциала',
#   'юфо',
#   'диссертация',
#   '..',
#   'доктора',
#   'экономических',
#   'наук',
#   '08.00.05'],
#  ['путеводитель', 'по', 'москве'],
#  ['полеты',
#   'над',
#   'бездной',
#   'искусство,',
#   'культура,',
#   'картина',
#   'мира,',
#   '1930-1990'],
#  ['модальные',
#   'и',
#   'каузативные',
#   'глаголы',
#   'в',
#   'современном',
#   'французском',
#   'языке',
#   'автореферат',
#   'дис..',
#   'доктора',
#   'филологических',
#   'наук',
#   '10.02.05'],
#  ['обучение',
#   'поиску',
#   'способа',
#   'решения',
#   'геометрической',
#   'задачи',
#   'учащихся',
#   'основной',
#   'школы',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.02'],
#  ['советское',
#   'нижнее',
#   'белье',
#   'между',
#   'идеологией',
#   'и',
#   'повседневностью'],
#  ['право',
#   'на',
#   'исправление',
#   'судебной',
#   'ошибки',
#   'как',
#   'компонент',
#   'судебной',
#   'защиты',
#   'автореферат',
#   'дис..',
#   'доктора',
#   'юридических',
#   'наук',
#   '12.00.15'],
#  ['стрелковая', 'подготовка', 'биатлониста', 'монография'],
#  ['возобновляемые',
#   'источники',
#   'энергии',
#   'материалы',
#   'всероссийской',
#   'научной',
#   'конференции',
#   'с',
#   'международным',
#   'участием',
#   'и',
#   'xi',
#   'научной',
#   'молодежной',
#   'школы,',
#   '3-6',
#   'декабря',
#   '2018',
#   'года,',
#   'москва'],
#  ['социально-географический',
#   'анализ',
#   'качества',
#   'жизни',
#   'населения',
#   'на',
#   'примере',
#   'самарской',
#   'области',
#   'диссертация',
#   '..',
#   'кандидата',
#   'географических',
#   'наук',
#   '25.00.24'],
#  ['институт',
#   'идентификации',
#   'в',
#   'информационном',
#   'праве',
#   'автореферат',
#   'дис..',
#   'доктора',
#   'юридических',
#   'наук',
#   '12.00.13'],
#  ['армяне', 'в', 'российских', 'исторических', 'документах'],
#  ['выкорчевать',
#   'до',
#   'конца',
#   'троцкистско-бухаринских',
#   'агентов',
#   'фашизма',
#   'сборник'],
#  ['социальная',
#   'регуляция',
#   'коммуникаций',
#   'в',
#   'организации',
#   'диссертация',
#   '..',
#   'кандидата',
#   'социологических',
#   'наук',
#   '22.00.08'],
#  ['отсутствует'],
#  ['безработица',
#   'в',
#   'современной',
#   'россии',
#   '=',
#   'unemployment',
#   'in',
#   'contemporary',
#   'russia'],
#  ['проблемы',
#   'лексикографического',
#   'описания',
#   'фразеологических',
#   'единиц',
#   'на',
#   'материале',
#   'английского,',
#   'русского',
#   'и',
#   'татарского',
#   'языков',
#   'автореферат',
#   'дис..',
#   'доктора',
#   'филологических',
#   'наук',
#   '10.02.20'],
#  ['отсутствует'],
#  ['феномен',
#   'московского',
#   'неофициального',
#   'искусства',
#   'позднесоветского',
#   'времени',
#   'эволюция,',
#   'социокультурный',
#   'контекст,',
#   'сообщества,',
#   'стратегии,',
#   'художественные',
#   'направления',
#   'диссертация',
#   '..',
#   'доктора',
#   'искусствоведения',
#   '17.00.04'],
#  ['символы', 'кельтов', 'пер.', 'с', 'нем.'],
#  ['разработка',
#   'комплексных',
#   'огнебиовлагозащитных',
#   'составов',
#   'с',
#   'использованием',
#   'термических',
#   'и',
#   'микологических',
#   'методов',
#   'анализа',
#   'диссертация',
#   '..',
#   'кандидата',
#   'технических',
#   'наук',
#   '05.26.03'],
#  ['грамматический',
#   'параллелизм',
#   'и',
#   'его',
#   'разновидности',
#   'как',
#   'средство',
#   'текстообразования',
#   'в',
#   'древнерусской',
#   'ораторской',
#   'прозе',
#   'xi',
#   '–',
#   'xvi',
#   'вв.',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.02.01'],
#  ['символизм', 'в', 'русской', 'живописи'],
#  ['русская', 'литература', 'миф', 'и', 'мифопоэтика', 'монография'],
#  ['общественно-политическая',
#   'деятельность',
#   'казахской',
#   'демократической',
#   'интеллигенции',
#   'в',
#   'i905-i907',
#   'гг.',
#   'автореферат',
#   'дис..',
#   'доктора',
#   'исторических',
#   'наук',
#   '07.00.02'],
#  ['теоретические',
#   'проблемы',
#   'в',
#   'сфере',
#   'осуществления',
#   'субъективных',
#   'гражданских',
#   'прав',
#   'диссертация',
#   '..',
#   'доктора',
#   'юридических',
#   'наук',
#   '12.00.03'],
#  ['лазеры',
#   'на',
#   'волоконных',
#   'световодах,',
#   'легированных',
#   'висмутом,',
#   'генерирующие',
#   'в',
#   'спектральном',
#   'диапазоне',
#   '1300-1550',
#   'нм',
#   'диссертация',
#   '..',
#   'кандидата',
#   'физико-математических',
#   'наук',
#   '01.04.21'],
#  ['отсутствует'],
#  ['лингво-дискурсивная',
#   'характеристика',
#   'терминов',
#   'зимнего',
#   'спорта',
#   'в',
#   'немецком',
#   'языке',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.02.04'],
#  ['отсутствует'],
#  ['эмоции', 'и', 'чувства'],
#  ['взаимодействие',
#   'международного',
#   'и',
#   'сравнительного',
#   'уголовного',
#   'права',
#   'учебное',
#   'пособие'],
#  ['теория', 'множеств'],
#  ['the', 'angels'],
#  ['основные',
#   'таблицы',
#   'стрельбы..',
#   'арт.',
#   'науч.-исслед.',
#   'морской',
#   'ин-т',
#   'воен.-морских',
#   'сил',
#   '203,2',
#   '(8-дм.)',
#   'орудий',
#   '50',
#   'калибров',
#   'длиной'],
#  ['государственно-правовые',
#   'закономерности',
#   'вопросы',
#   'теории',
#   'и',
#   'методологии',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.01'],
#  ['обучение',
#   'диалогу-обсуждению',
#   'учащихся',
#   'старших',
#   'классов',
#   'в',
#   'школе',
#   'с',
#   'углубленным',
#   'изучением',
#   'английского',
#   'языка',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.02'],
#  ['руководство', 'по', 'практической', 'стоматологии'],
#  ['злоупотребление',
#   'правом',
#   'в',
#   'сфере',
#   'налогов',
#   'и',
#   'сборов',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.14'],
#  ['реклама',
#   'как',
#   'форма',
#   'социальной',
#   'деятельности',
#   '(актуальные',
#   'проблемы)'],
#  ['разработка',
#   'метода',
#   'бесконтактной',
#   'заточки',
#   'и',
#   'поверхностной',
#   'модификации',
#   'пучками',
#   'быстрых',
#   'атомов',
#   'режущего',
#   'инструмента',
#   'для',
#   'чистовой',
#   'обработки',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'технических',
#   'наук',
#   '05.02.07'],
#  ['методика',
#   'учета',
#   'влияния',
#   'границ',
#   'потока',
#   'при',
#   'испытаниях',
#   'в',
#   'трансзвуковой',
#   'аэродинамической',
#   'трубе',
#   'с',
#   'проницаемыми',
#   'стенками',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'технических',
#   'наук',
#   '05.07.01'],
#  ['современная', 'медицинская', 'энциклопедия'],
#  ['отсутствует'],
#  ['геометрическое',
#   'моделирование',
#   'трехмерных',
#   'объектов',
#   'с',
#   'помощью',
#   'их',
#   'мономоделей',
#   'с',
#   'использованиемспециальных',
#   'координат',
#   'в',
#   'плоскости',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'технических',
#   'наук',
#   '05.01.01'],
#  ['незаконное',
#   'производство',
#   'и',
#   'оборот',
#   'алкогольной',
#   'продукции',
#   'уголовно-правовые',
#   'и',
#   'криминологические',
#   'аспекты',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.08'],
#  ['уголовно-правовые',
#   'и',
#   'криминологические',
#   'меры',
#   'борьбы',
#   'с',
#   'незаконным',
#   'оборотом',
#   'подакцизных',
#   'товаров',
#   'и',
#   'продукции',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.08'],
#  ['национальная', 'политика', 'и', 'задачи', 'советов'],
#  ['отсутствует'],
#  ['судебные', 'доказательства'],
#  ['процесс',
#   'консолидации',
#   'армянского',
#   'народа',
#   'в',
#   'восточной',
#   'армении',
#   'в',
#   'конце',
#   '20-х',
#   '-',
#   'начале',
#   '30-х',
#   'годов',
#   'xix',
#   'века',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'исторических',
#   'наук',
#   '07.00.02'],
#  ['отсутствует'],
#  ['революционное',
#   'движение',
#   'военных',
#   'годов',
#   '(1914-1917)',
#   'очерки',
#   'и',
#   'материалы',
#   'ив.',
#   'меницкий',
#   ';',
#   'коммунистическая',
#   'академия,',
#   'кабинет',
#   'истории',
#   'общественной',
#   'мысли',
#   'и',
#   'революционного',
#   'движения',
#   'в',
#   'россии',
#   'первый',
#   'год',
#   'войны',
#   '(москва)'],
#  ['институт',
#   'полномочных',
#   'представителей',
#   'президента',
#   'российской',
#   'федерации',
#   'в',
#   'федеральных',
#   'округах',
#   'история',
#   'становления',
#   'и',
#   'конституционно-правовые',
#   'основы',
#   'деятельности',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.02'],
#  ['восточные',
#   'традиции',
#   'в',
#   'творческом',
#   'восприятии',
#   'и.а.',
#   'бунина',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.01.01'],
#  ['вербальные',
#   'способы',
#   'выражения',
#   'глорификации',
#   'в',
#   'русском',
#   'языке',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.02.01'],
#  ['содержание',
#   'коммуникативной',
#   'компетенции',
#   'иностранцев',
#   'при',
#   'использовании',
#   'русского',
#   'языка',
#   'в',
#   'сфере',
#   'международного',
#   'туристского',
#   'бизнеса',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.02'],
#  ['народный',
#   'костюм',
#   'в',
#   'контексте',
#   'традиций',
#   'российской',
#   'культуры',
#   'диссертация',
#   '..',
#   'доктора',
#   'культурол.',
#   'наук',
#   '24.00.02'],
#  ['управление',
#   'инновационными',
#   'экосистемами',
#   'на',
#   'основе',
#   'развития',
#   'цифровых',
#   'технологий',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'экономических',
#   'наук',
#   '08.00.05'],
#  ['правовое',
#   'регулирование',
#   'предпринимательской',
#   'деятельности',
#   'в',
#   'сфере',
#   'долевого',
#   'строительства',
#   'объектов',
#   'недвижимости',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.03'],
#  ['унификация',
#   'норм,',
#   'регулирующих',
#   'трудовые',
#   'отношения',
#   'в',
#   'международном',
#   'частном',
#   'праве',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.03'],
#  ['репродуктивное',
#   'поведение',
#   'как',
#   'объект',
#   'социологического',
#   'исследования',
#   'диссертация',
#   '..',
#   'кандидата',
#   'социологических',
#   'наук',
#   '22.00.04'],
#  ['формирование',
#   'общепедагогической',
#   'икт-компетентности',
#   'будущего',
#   'учителя',
#   'на',
#   'основе',
#   'системно-деятельностного',
#   'подхода',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.08'],
#  ['роль',
#   'презумпций',
#   'и',
#   'фикций',
#   'в',
#   'распределении',
#   'обязанностей',
#   'по',
#   'доказыванию'],
#  ['изометрические',
#   'полиэдральные',
#   'подграфы',
#   'в',
#   'гиперкубах',
#   'и',
#   'кубических',
#   'решетках',
#   'монография'],
#  ['формирование',
#   'организационно-экономического',
#   'механизма',
#   'эффективного',
#   'управления',
#   'предприятиями',
#   'санаторно-курортного',
#   'комплекса',
#   'на',
#   'примере',
#   'республики',
#   'крым',
#   'диссертация',
#   '..',
#   'кандидата',
#   'экономических',
#   'наук',
#   '08.00.05'],
#  ['русско-японская',
#   'война',
#   '1904-1905',
#   'гг.',
#   'действия',
#   'флота.',
#   'документы',
#   'отд.',
#   '1-4',
#   'отд.',
#   '1.',
#   'тихоокеанская',
#   'эскадра',
#   'с',
#   '1894',
#   'по',
#   '1904',
#   'г.',
#   'кн.',
#   '2.',
#   'занятие',
#   'порт-артура',
#   'и',
#   'квантунской',
#   'области'],
#  ['методическая',
#   'система',
#   'углубленного',
#   'обучения',
#   'информатике',
#   'на',
#   'основе',
#   'интегративного',
#   'подхода',
#   'автореферат',
#   'дис..',
#   'доктора',
#   'педагогических',
#   'наук',
#   '13.00.02'],
#  ['понятие', 'права'],
#  ['биоразлагаемые',
#   'полимерные',
#   'композиции,',
#   'модифицированные',
#   'ультразвуковой',
#   'обработкой',
#   'в',
#   'процессе',
#   'экструзии',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'технических',
#   'наук',
#   '05.17.06'],
#  ['гениальность', 'и', 'помешательство'],
#  ['"прометей"',
#   'а.н.',
#   'скрябина',
#   'проблема',
#   'синтеза',
#   'музыки',
#   'и',
#   'света',
#   'диссертация',
#   '..',
#   'кандидата',
#   'искусствоведения',
#   '17.00.02'],
#  ['комплексный',
#   'подход',
#   'к',
#   'реструктурированию',
#   'предприятий',
#   'в',
#   'условиях',
#   'трансформации',
#   'диссертация',
#   '..',
#   'кандидата',
#   'экономических',
#   'наук',
#   '08.00.05'],
#  ['стессель', 'анатолий', 'михайлович', 'архивный', 'фонд,', '1843-1909'],
#  ['уголовно-правовая',
#   'оценка',
#   'единичного',
#   'сложного',
#   'преступления',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.08'],
#  ['влияние',
#   'высоких',
#   'температур',
#   'на',
#   'оптические',
#   'потери',
#   'в',
#   'волоконных',
#   'световодах',
#   'с',
#   'металлическими',
#   'покрытиями',
#   'диссертация',
#   '..',
#   'кандидата',
#   'физико-математических',
#   'наук',
#   '01.04.21'],
#  ['физика', 'плазмы', 'и', 'численное', 'моделирование'],
#  ['отсутствует'],
#  ['отсутствует'],
#  ['отсутствует'],
#  ['разработка',
#   'методики',
#   'формирования',
#   'комплексов',
#   'формного',
#   'оборудования',
#   'диссертация',
#   '..',
#   'кандидата',
#   'технических',
#   'наук',
#   '05.02.13'],
#  ['отсутствует'],
#  ['пластика',
#   'и',
#   'пространство,',
#   'как',
#   'основные',
#   'формы',
#   'художественного',
#   'выражения'],
#  ['осторожно,',
#   'близнецы!',
#   'роман',
#   'для',
#   'детей',
#   'для',
#   'среднего',
#   'школьного',
#   'возраста',
#   '0+'],
#  ['транспортные',
#   'обязательства',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.03'],
#  ['методическая',
#   'система',
#   'вокального',
#   'развития',
#   'студентов',
#   'различных',
#   'исполнительских',
#   'специальностей',
#   'в',
#   'условиях',
#   'вузовского',
#   'образования',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.02'],
#  ['политический',
#   'процесс',
#   'в',
#   'канаде',
#   'традиции',
#   'и',
#   'современность',
#   'диссертация',
#   '..',
#   'кандидата',
#   'политических',
#   'наук',
#   '23.00.02'],
#  ['математическое',
#   'моделирование',
#   'неравновесных',
#   'процессов',
#   'детонации',
#   'и',
#   'горения,',
#   'а',
#   'также',
#   'переходных',
#   'режимов',
#   'на',
#   'многопроцессорных',
#   'эвм',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'физико-математических',
#   'наук',
#   '01.02.05'],
#  ['социокультурные',
#   'детерминанты',
#   'русского',
#   'менталитета',
#   'диссертация',
#   '..',
#   'кандидата',
#   'философских',
#   'наук',
#   '24.00.01'],
#  ['пределы',
#   'правового',
#   'пространства',
#   'свободы',
#   'прессы',
#   '(российские',
#   'споры',
#   'с',
#   'участием',
#   'сми',
#   'в',
#   'контексте',
#   'мировой',
#   'практики)'],
#  ['император',
#   'александр',
#   'первый,',
#   'его',
#   'жизнь',
#   'и',
#   'царствование',
#   'с',
#   '450',
#   'ил.',
#   'н.',
#   'к.',
#   'шильдера',
#   'т.',
#   '1'],
#  ['историческое',
#   'обозрение',
#   'торговых',
#   'сношений',
#   'новагорода',
#   'с',
#   'готландом',
#   'и',
#   'любеком',
#   'рассуждение,',
#   'представл.',
#   'м.',
#   'славянским',
#   'в',
#   'первое',
#   'отд-ние',
#   'филос.',
#   'фак.',
#   'с.-петерб.',
#   'ун-та',
#   'для',
#   'получения',
#   'степ.',
#   'магистра',
#   'рус.',
#   'истории'],
#  ['тексты',
#   'телевизионных',
#   'новостных',
#   'передач',
#   'лингвопрагматический',
#   'анализ',
#   'на',
#   'примере',
#   'программ',
#   'телеканалов',
#   '"первый",',
#   '"россия-1",',
#   'нтв,',
#   '"евроньюс"',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.01.10'],
#  ['концепт',
#   '"еда"',
#   'как',
#   'фрагмент',
#   'языковой',
#   'картины',
#   'мира',
#   'лексико-семантический',
#   'и',
#   'когнитивно-прагматический',
#   'аспекты',
#   'на',
#   'материале',
#   'русского',
#   'и',
#   'английского',
#   'языков',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.02.19'],
#  ['цру', 'и', 'другие', 'спецслужбы', 'сша'],
#  ['корейский',
#   'художественный',
#   'металл',
#   'xix',
#   '-',
#   'xx',
#   'веков',
#   'истоки.',
#   'эволюция.',
#   'традиция',
#   'диссертация',
#   '..',
#   'кандидата',
#   'культурол.',
#   'наук',
#   '24.00.02'],
#  ['медико-географический',
#   'подход',
#   'к',
#   'интеграции',
#   'знаний',
#   'о',
#   'здоровье',
#   'населения',
#   'на',
#   'региональном',
#   'уровне',
#   'диссертация',
#   '..',
#   'доктора',
#   'географических',
#   'наук',
#   '25.00.24'],
#  ['безотзывная',
#   'доверенность',
#   'в',
#   'гражданском',
#   'праве',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.03'],
#  ['отсутствует'],
#  ['памятники',
#   'российского',
#   'права',
#   'учебно-научное',
#   'пособие',
#   'в',
#   '35',
#   'т.',
#   'бобровский',
#   'олег',
#   'викторович',
#   'и',
#   'др.',
#   ';',
#   'под',
#   'общ.',
#   'ред.',
#   'р.',
#   'л.',
#   'хачатурова',
#   'спецслужбы',
#   'российской',
#   'империи'],
#  ['агентский',
#   'договор',
#   'в',
#   'системе',
#   'посреднических',
#   'сделок',
#   'в',
#   'российском',
#   'гражданском',
#   'праве',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.03'],
#  ['отсутствует'],
#  ['интернет-медиа',
#   'в',
#   'коммуникативном',
#   'пространстве',
#   'современного',
#   'мегаполиса',
#   'на',
#   'примере',
#   'города',
#   'москвы',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.01.10'],
#  ['экологическая',
#   'функция',
#   'государства',
#   'теория',
#   'и',
#   'практика',
#   'реализации',
#   'монография'],
#  ['экспериментально-клиническое',
#   'обоснование',
#   'возможности',
#   'эндопротезирования',
#   'в',
#   'кистевом',
#   'суставе',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'медицинских',
#   'наук',
#   '14.00.22'],
#  ['певческие',
#   'традиции',
#   'региона',
#   'как',
#   'фактор',
#   'оптимизации',
#   'художественного',
#   'развития',
#   'личности',
#   'на',
#   'примере',
#   'этнокультурных',
#   'традиций',
#   'новгородской',
#   'земли',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.05'],
#  ['средства',
#   'предикации',
#   'в',
#   'романе',
#   'в.',
#   'пелевина',
#   '"generation',
#   'п"',
#   'и',
#   'их',
#   'художественно-стилистическое',
#   'использование',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.02.01'],
#  ['основы', 'дерматологии'],
#  ['население',
#   'и',
#   'экология',
#   'жужелиц',
#   'на',
#   'севере',
#   'ямала',
#   'диссертация',
#   '..',
#   'кандидата',
#   'биологических',
#   'наук',
#   '03.00.16'],
#  ['воспоминания'],
#  ['проблемы',
#   'становления',
#   'и',
#   'развития',
#   'судебной',
#   'власти',
#   'в',
#   'российской',
#   'федерации',
#   'диссертация',
#   '..',
#   'доктора',
#   'юридических',
#   'наук',
#   '12.00.02'],
#  ['отсутствует'],
#  ['современные',
#   'возможности',
#   'визуализации',
#   'в',
#   'офтальмологии',
#   'на',
#   'основе',
#   'ультразвуковой',
#   'биомикроскопии',
#   'автореферат',
#   'дис..',
#   'доктора',
#   'медицинских',
#   'наук',
#   '14.01.07'],
#  ['математические',
#   'и',
#   'вычислительные',
#   'задачи',
#   'магнитной',
#   'газодинамики'],
#  ['трудовой',
#   'стаж',
#   'и',
#   'его',
#   'роль',
#   'в',
#   'праве',
#   'социального',
#   'обеспечения',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.05'],
#  ['современный',
#   'политический',
#   'процесс',
#   'в',
#   'чеченской',
#   'республике',
#   'институциональный',
#   'аспект',
#   'диссертация',
#   '..',
#   'кандидата',
#   'политических',
#   'наук',
#   '23.00.02'],
#  ['суицидологическая',
#   'характеристика',
#   'женщин,',
#   'страдающих',
#   'алкогольной',
#   'зависимостью',
#   'диссертация',
#   '..',
#   'кандидата',
#   'медицинских',
#   'наук',
#   '14.01.27'],
#  ['научные',
#   'основы',
#   'формирования',
#   'высокопродуктивных',
#   'агроценозов',
#   'однолетних',
#   'кормовых',
#   'культур',
#   'в',
#   'лесостепи',
#   'среднего',
#   'поволжья',
#   'монография'],
#  ['социальная',
#   'структура',
#   'колхозного',
#   'крестьянства',
#   'и',
#   'тенденция',
#   'её',
#   'изменения',
#   'в',
#   'период',
#   'строительства',
#   'коммунизма',
#   '(на',
#   'материалах',
#   'казахстана',
#   '621',
#   '-',
#   'научный',
#   'коммунизм)',
#   'автореф.',
#   'дисс.',
#   'на',
#   'соискание',
#   'учёной',
#   'степени',
#   'кандидата',
#   'философских',
#   'наук',
#   'на',
#   'правах',
#   'рукописи'],
#  ['имущественные',
#   'меры',
#   'бюджетно-правового',
#   'принуждения',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.14'],
#  ['функционирование',
#   'фразеологизмов',
#   'в',
#   'устном',
#   'дискурсе',
#   'на',
#   'материале',
#   'спортивных',
#   'репортажей',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.02.01'],
#  ['отсутствует'],
#  ['отсутствует'],
#  ['отсутствует'],
#  ['основы',
#   'современного',
#   'учения',
#   'о',
#   'юридических',
#   'фикциях',
#   'в',
#   'праве',
#   'россии',
#   'монография'],
#  ['памятная',
#   'книжка',
#   'области',
#   'войска',
#   'донского..',
#   '..',
#   'на',
#   '1876',
#   'год'],
#  ['исторические',
#   'аспекты',
#   'цивилизационной',
#   'политики',
#   'царской',
#   'россии',
#   'в',
#   'средней',
#   'азии',
#   'автореферат',
#   'дис..',
#   'доктора',
#   'исторических',
#   'наук',
#   '07.00.02'],
#  ['отсутствует'],
#  ['современная',
#   'экономическая',
#   'терминология',
#   'в',
#   'республике',
#   'корея',
#   'лингвистический',
#   'анализ',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.02.22'],
#  ['феномен',
#   'остроумия',
#   'в',
#   'поэзии',
#   'джона',
#   'донна',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.01.05'],
#  ['российская',
#   'империя',
#   'в',
#   'фотографиях.',
#   'конец',
#   'xix',
#   '-',
#   'начало',
#   'xx',
#   'века',
#   '=',
#   'russian',
#   'empire',
#   'in',
#   'photographs.',
#   'end',
#   'of',
#   'xx',
#   '-',
#   'eginning',
#   'of',
#   'xx',
#   'century'],
#  ['отсутствует'],
#  ['поведение', 'потребителей', 'учеб.', 'по', 'специальности', '"маркетинг"'],
#  ['смешанная',
#   'краевая',
#   'задача',
#   'метания',
#   'стержня',
#   'из',
#   'упруговязкопластического',
#   'материала',
#   'с',
#   'учетом',
#   'термодинамических',
#   'эффектов',
#   'диссертация',
#   '..',
#   'кандидата',
#   'технических',
#   'наук',
#   '01.02.04'],
#  ['история',
#   'министерства',
#   'внутренних',
#   'дел',
#   'соч.',
#   'д-ра',
#   'прав',
#   'и',
#   'философии',
#   'н.',
#   'варадинова.',
#   'ч.',
#   '1-3',
#   'период',
#   'третий',
#   'с',
#   '19',
#   'ноября',
#   '1825',
#   'по',
#   '20',
#   'августа',
#   '1855',
#   'г.'],
#  ['отсутствует'],
#  ['концепты',
#   '«пространство»',
#   'и',
#   '«время»',
#   'в',
#   'фольклорном',
#   'жанре',
#   'русской',
#   'частушки',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.02.01'],
#  ['прокуратура',
#   'и',
#   'прокурорский',
#   'надзор',
#   'россии',
#   'в',
#   'xviii-начале',
#   'xx',
#   'вв.',
#   'историко-правовое',
#   'исследование',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.01'],
#  ['homo', 'lingualis', 'в', 'культуре', 'монография'],
#  ['размышление.',
#   'три',
#   'романса',
#   'ноты',
#   'для',
#   'гобоя',
#   'и',
#   'ф-но.',
#   'клавир',
#   'и',
#   'партия'],
#  ['материалы',
#   'для',
#   'описания',
#   'русских',
#   'рек',
#   'и',
#   'истории',
#   'улучшения',
#   'их',
#   'судоходных',
#   'условий',
#   'упр.',
#   'внутренних',
#   'водных',
#   'путей',
#   'и',
#   'шоссейных',
#   'дорог',
#   'очерк',
#   'землечерпательных',
#   'работ',
#   'в',
#   'рукаве',
#   'реки',
#   'волги',
#   'у',
#   'гор.',
#   'саратова'],
#  ['история',
#   'восприятия',
#   'и',
#   'истолкований',
#   'пьесы',
#   'а.',
#   'п.',
#   'чехова',
#   '«дядя',
#   'ваня»',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.01.01'],
#  ['разработка',
#   'направлений',
#   'повышения',
#   'эффективности',
#   'технологической',
#   'подготовки',
#   'производства',
#   'деталей',
#   'и',
#   'узлов',
#   'ракетно-космической',
#   'техники',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'технических',
#   'наук',
#   '05.02.07,',
#   '05.02.08'],
#  ['получение',
#   'биологически',
#   'активных',
#   'производных',
#   'индолизинов,',
#   'пирролоизохинолинов',
#   'и',
#   'конденсированных',
#   'азепинов',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'химических',
#   'наук',
#   '1.4.3.'],
#  ['научные',
#   'основы',
#   'профилактики',
#   'нарушения',
#   'здоровья',
#   'медицинских',
#   'работников',
#   '(на',
#   'примере',
#   'города',
#   'владивостока)',
#   'диссертация',
#   '..',
#   'кандидата',
#   'медицинских',
#   'наук',
#   '14.00.07'],
#  ['экономические',
#   'основы',
#   'финансового',
#   'механизма',
#   'в',
#   'сельском',
#   'хозяйстве',
#   'на',
#   'материалах',
#   'калужской',
#   'области',
#   'диссертация',
#   '..',
#   'кандидата',
#   'экономических',
#   'наук',
#   '08.00.05'],
#  ['системная', 'социология', 'введение', 'в', 'анализ', 'динамики', 'социума'],
#  ['индивидуальный',
#   'образовательный',
#   'маршрут',
#   'как',
#   'средство',
#   'развития',
#   'готовности',
#   'старшего',
#   'подростка',
#   'к',
#   'профильному',
#   'выбору',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.01'],
#  ['медицинская',
#   'реабилитация',
#   'больных',
#   'ранним',
#   'ревматоидным',
#   'артритом',
#   'диссертация',
#   '..',
#   'доктора',
#   'медицинских',
#   'наук',
#   '14.01.22',
#   '14.03.11'],
#  ['русский',
#   'биографический',
#   'словарь',
#   'изд.',
#   'под',
#   'наблюдением',
#   'пред.',
#   'имп.',
#   'рус.',
#   'ист.',
#   'о-ва',
#   'а.',
#   'а.',
#   'половцова',
#   'нааке-накенский',
#   '-',
#   'николай',
#   'николаевич',
#   'старший'],
#  ['преступное',
#   'сообщество',
#   'сравнительный',
#   'криминолого-правовой',
#   'анализ',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.08'],
#  ['полистилистика',
# ...
#   'советской',
#   'энциклопедии',
#   'гл.',
#   'ред.',
#   'б.',
#   'а.',
#   'введенский',
#   '1979'],
#  ['медиакратия',
#   'и',
#   'ее',
#   'роль',
#   'в',
#   'урегулировании',
#   'политических',
#   'конфликтов',
#   'на',
#   'примере',
#   'российско-грузинского',
#   'конфликта',
#   '2008',
#   'г.',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'политических',
#   'наук',
#   '23.00.02'],
#  ['европа',
#   'перемен',
#   'концепции',
#   'и',
#   'стратегии',
#   'интеграционных',
#   'процессов',
#   'монография'],
#  ['нормально-фазовая',
#   'изократическая',
#   'вэжх',
#   'жирорастворимых',
#   'витаминов',
#   'закономерности',
#   'удерживания,',
#   'оптимизация',
#   'состава',
#   'подвижной',
#   'фазы',
#   'и',
#   'разработка',
#   'аналитических',
#   'методик',
#   'диссертация',
#   '..',
#   'кандидата',
#   'химических',
#   'наук',
#   '02.00.02'],
#  ['княгиня',
#   'ливен',
#   '=',
#   'princess',
#   'lieven',
#   '=',
#   'la',
#   'princesse',
#   'de',
#   'lieven',
#   'любовь,',
#   'политика,',
#   'дипломатия'],
#  ['теоретические',
#   'проблемы',
#   'монархической',
#   'формы',
#   'правления',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.01'],
#  ['отсутствует'],
#  ['отсутствует'],
#  ['правовая',
#   'регламентация',
#   'отношений',
#   'супругов',
#   'и',
#   'бывших',
#   'супругов',
#   'по',
#   'предоставлению',
#   'содержания',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.03'],
#  ['научные',
#   'школы',
#   'в',
#   'археологии',
#   'диссертация',
#   '..',
#   'доктора',
#   'исторических',
#   'наук',
#   '07.00.06'],
#  ['список',
#   'дворянских',
#   'родов,',
#   'внесенных',
#   'в',
#   'родословные',
#   'дворянские',
#   'книги',
#   'смоленской',
#   'губернии',
#   'сост.',
#   'в',
#   '1897',
#   'г.'],
#  ['хронические',
#   'болевые',
#   'и',
#   'парестетические',
#   'синдромы',
#   'языка',
#   'клиника,',
#   'диагностика,',
#   'лечение,',
#   'профилактика',
#   'и',
#   'организация',
#   'лечебного',
#   'процесса',
#   'диссертация',
#   '..',
#   'доктора',
#   'медицинских',
#   'наук',
#   '14.01.14'],
#  ['фольклорные',
#   'и',
#   'литературные',
#   'архетипы',
#   'в',
#   'поэтике',
#   'н.в.',
#   'гоголя',
#   'диссертация',
#   '..',
#   'доктора',
#   'филологических',
#   'наук',
#   '10.01.01'],
#  ['повышение',
#   'эффективности',
#   'функционирования',
#   'высоковольтных',
#   'мехатронных',
#   'модулей',
#   'на',
#   'основе',
#   'диагностики',
#   'технического',
#   'состояния',
#   'диссертация',
#   '..',
#   'кандидата',
#   'технических',
#   'наук',
#   '05.02.05'],
#  ['характер',
#   'влияния',
#   'рекламных',
#   'коммуникаций',
#   'на',
#   'культурно-психологические',
#   'процессы',
#   'межнационального',
#   'взаимодействия',
#   'в',
#   'россии.',
#   'теоретико-социологический',
#   'анализ',
#   'диссертация',
#   '..',
#   'кандидата',
#   'социологических',
#   'наук',
#   '22.00.01'],
#  ['что',
#   'такое',
#   'право?',
#   'теория',
#   'позитив.',
#   'права',
#   'и',
#   'теория',
#   'нравственности'],
#  ['отсутствует'],
#  ['вина', 'в', 'советском', 'уголовном', 'праве', 'монография'],
#  ['отсутствует'],
#  ['структурно-семантические',
#   'типы',
#   'сложных',
#   'эпитетов',
#   'в',
#   'языковой',
#   'картине',
#   'мира',
#   'писателя',
#   'на',
#   'материале',
#   'художественной',
#   'прозы',
#   'ю.',
#   'нагибина',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.02.01'],
#  ['прогнозирование',
#   'аутоагрессивного',
#   'поведения',
#   'осужденных',
#   'в',
#   'исправительных',
#   'учреждениях',
#   'диссертация',
#   '..',
#   'кандидата',
#   'психологических',
#   'наук',
#   '19.00.06'],
#  ['определение',
#   'концентрационной',
#   'зависимости',
#   'коэффициента',
#   'диффузии',
#   'водорода',
#   'в',
#   'металлах',
#   'в',
#   'условиях',
#   'нестационарного',
#   'проникновения',
#   'диссертация',
#   '..',
#   'кандидата',
#   'химических',
#   'наук',
#   '02.00.04'],
#  ['поэтика',
#   'кино',
#   '(2.',
#   'изд.)',
#   'перечитывая',
#   '"поэтику',
#   'кино"',
#   'м-во',
#   'культуры',
#   'рос.',
#   'федерации,',
#   'рос.',
#   'акад.',
#   'наук,',
#   'рос.',
#   'ин-т',
#   'истории',
#   'искусств,',
#   'под',
#   'общ.',
#   'ред.',
#   'р.',
#   'д.',
#   'копыловой'],
#  ['социальная',
#   'идентичность',
#   'квир-подростков',
#   'каминг-аут',
#   'в',
#   'семье',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'социологических',
#   'наук',
#   '22.00.04'],
#  ['лексическая',
#   'лакунарность',
#   'и',
#   'ее',
#   'отражение',
#   'в',
#   'переводе',
#   'на',
#   'материале',
#   'русского',
#   'и',
#   'испанского',
#   'языков',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.02.20'],
#  ['этические',
#   'основы',
#   'уголовно-процессуальной',
#   'деятельности',
#   'адвоката-защитника',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.09'],
#  ['разработка',
#   'технологии',
#   'отбойки',
#   'пород',
#   'гидромонитором',
#   'при',
#   'наличии',
#   'в',
#   'его',
#   'струе',
#   'твердых',
#   'частиц',
#   'различной',
#   'крупности',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'технических',
#   'наук',
#   '25.00.22'],
#  ['варвара',
#   'алексеевна',
#   'морозова.',
#   'на',
#   'благо',
#   'просвещения',
#   'москвы',
#   'в',
#   '2',
#   'т.',
#   'библиотека-читальня',
#   'им.',
#   'и.',
#   'с.',
#   'тургенева',
#   ';',
#   'сост.,',
#   'подгот.',
#   'текстов,',
#   'примеч.',
#   'н.',
#   'а.',
#   'круглянской',
#   'благотворительная',
#   'деятельность',
#   'в.',
#   'а.',
#   'морозовой',
#   'и',
#   'ее',
#   'родственников',
#   'морозовская',
#   'мануфактура',
#   'в',
#   'твери',
#   ',',
#   'в.',
#   'м.',
#   'соболевский',
#   'и',
#   '"русские',
#   'ведомости"',
#   ',',
#   'общественно-политическая',
#   'деятельность',
#   'в.',
#   'а.',
#   'морозовой',
#   ',',
#   'дети',
#   'в.',
#   'а.',
#   'морозовой',
#   'и',
#   'их',
#   'семьи',
#   ',',
#   'памяти',
#   'в.',
#   'а.',
#   'морозовой'],
#  ['оценка',
#   'стоимости',
#   'прав',
#   'владения',
#   'и',
#   'распоряжения',
#   'земельными',
#   'участками',
#   'как',
#   'инвестиционного',
#   'ресурса',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'экономических',
#   'наук',
#   '08.00.05'],
#  ['особенности',
#   'правового',
#   'статуса',
#   'потерпевшего',
#   'на',
#   'стадии',
#   'предварительного',
#   'расследования',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.09'],
#  ['формирование',
#   'профессионально-личностных',
#   'мотивов',
#   'изучения',
#   'иностранного',
#   'языка',
#   'у',
#   'студентов',
#   'технического',
#   'колледжа',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.08'],
#  ['феномен', 'смыслообразования', 'в', 'киноискусстве', 'монография'],
#  ['нейрофизиологические',
#   'аспекты',
#   'оценки',
#   'степени',
#   'тяжести',
#   'и',
#   'прогнозирования',
#   'исходов',
#   'перинатальных',
#   'постгипоксических',
#   'поражений',
#   'головного',
#   'мозга',
#   'у',
#   'детей',
#   'различного',
#   'гестационного',
#   'возраста',
#   'при',
#   'лонгитудинальном',
#   'наблюдении',
#   'автореферат',
#   'дис..',
#   'доктора',
#   'медицинских',
#   'наук',
#   '14.00.09'],
#  ['семиотика', 'политического', 'дискурса'],
#  ['фурановые', 'смолы', '(производство', 'и', 'применение)', 'обзор'],
#  ['внешняя',
#   'политика',
#   'ссср',
#   'сборник',
#   'документов',
#   'высш.',
#   'парт.',
#   'школа',
#   'при',
#   'цк',
#   'вкп(б),',
#   'кабинет',
#   'соц.-экон.',
#   'наук',
#   ';',
#   'отв.',
#   'ред.',
#   'с.',
#   'а.',
#   'лозовский',
#   ';',
#   'ред.',
#   'и',
#   'авт.',
#   'прим.',
#   'проф.',
#   'б.',
#   'е.',
#   'штейн',
#   'т.',
#   '4',
#   '(1935',
#   '-',
#   'июнь',
#   '1941',
#   'г.)'],
#  ['финансовые',
#   'и',
#   'нефинансовые',
#   'детерминанты',
#   'в',
#   'оценке',
#   'стоимости',
#   'бизнеса',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'экономических',
#   'наук',
#   '08.00.10'],
#  ['отсутствует'],
#  ['совершенствование',
#   'технологии',
#   'получения,',
#   'хранения',
#   'и',
#   'переработки',
#   'перги',
#   'диссертация',
#   '..',
#   'кандидата',
#   'биологических',
#   'наук',
#   '06.02.10'],
#  ['отсутствует'],
#  ['отсутствует'],
#  ['12', 'прогулок', 'по', 'москве'],
#  ['повышение',
#   'эффективности',
#   'ремонта',
#   'бетонных',
#   'облицовок',
#   'оросительных',
#   'каналов',
#   'композитными',
#   'материалами',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'технических',
#   'наук',
#   '06.01.02'],
#  ['крестьяне',
#   'псковской',
#   'губернии',
#   'в',
#   'годы',
#   'гражданской',
#   'войны',
#   '1917',
#   '-',
#   '1920',
#   'гг.',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'исторических',
#   'наук',
#   '07.00.02'],
#  ['мультикультурный',
#   'контекст',
#   'современного',
#   'английского',
#   'романа',
#   'диссертация',
#   '..',
#   'доктора',
#   'филологических',
#   'наук',
#   '10.01.03'],
#  ['структурно-семантические',
#   'особенности',
#   'молодежного',
#   'сленга',
#   'в',
#   'английском',
#   'и',
#   'французском',
#   'языках',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.02.20'],
#  ['модели',
#   'и',
#   'алгоритмы',
#   'обоснования',
#   'величины',
#   'индивидуального',
#   'пожарного',
#   'риска',
#   'для',
#   'управления',
#   'безопасностью',
#   'людей',
#   'в',
#   'зданиях',
#   'и',
#   'сооружениях',
#   'диссертация',
#   '..',
#   'кандидата',
#   'технических',
#   'наук',
#   '05.13.10'],
#  ['педагогическая',
#   'модель',
#   'формирования',
#   'технической',
#   'компетентности',
#   'курсантов',
#   'высшего',
#   'военного',
#   'учебного',
#   'заведения',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.08'],
#  ['по', 'монголии', 'и', 'тибету'],
#  ['совершенствование',
#   'технологии',
#   'твердофазного',
#   'синтеза',
#   'натриевой',
#   'соли',
#   'карбоксиметилцеллюлозы',
#   'с',
#   'заданной',
#   'степенью',
#   'полимеризации',
#   'диссертация',
#   '..',
#   'кандидата',
#   'технических',
#   'наук',
#   '05.17.06'],
#  ['духовно-нравственные',
#   'основания',
#   'традиционного',
#   'уклада',
#   'жизни',
#   'как',
#   'социально-педагогическая',
#   'проблема',
#   'автореферат',
#   'дис..',
#   'доктора',
#   'педагогических',
#   'наук',
#   '13.00.01'],
#  ['интегративная',
#   'модель',
#   'обучения',
#   'иностранных',
#   'студентов',
#   'русской',
#   'деловой',
#   'коммуникации',
#   'на',
#   'основе',
#   'кейс-технологии',
#   'и',
#   'медиаресурсов',
#   'направление',
#   '"экономика",',
#   'уровни',
#   'в1-в2',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.02'],
#  ['письма', 'из', 'похода', 'к', 'цусиме'],
#  ['передача',
#   'возрастных',
#   'и',
#   'гендерных',
#   'особенностей',
#   'идиолекта',
#   'при',
#   'переводе',
#   'произведений',
#   'художественной',
#   'литературы',
#   'с',
#   'английского',
#   'языка',
#   'на',
#   'русский',
#   'диссертация',
#   '..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.02.20'],
#  ['перечень',
#   'нормативных',
#   'актов',
#   'госстандарта',
#   'ссср',
#   'отмененных',
#   'и',
#   'измененных',
#   'в',
#   'соответствии',
#   'с',
#   'законом',
#   'ссср',
#   '"о',
#   'государственном',
#   'предприятии',
#   '(объединении)"',
#   '(по',
#   'системе',
#   'госстандарта)'],
#  ['правовое',
#   'регулирование',
#   'крупных',
#   'сделок',
#   'юридических',
#   'лиц',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.03'],
#  ['законная', 'сила', 'судебных', 'решений', 'по', 'делам', 'гражданским'],
#  ['возникновение',
#   'ранних',
#   'англосаксонских',
#   'государств',
#   'дискуссионные',
#   'проблемы',
#   'и',
#   'эволюция',
#   'концепций',
#   'в',
#   'историко-археологическом',
#   'дискурсе',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'исторических',
#   'наук',
#   '07.00.03'],
#  ['организация',
#   'и',
#   'управление',
#   'маркетингом',
#   'на',
#   'предприятиях',
#   'молочного',
#   'направления',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'экономических',
#   'наук',
#   '08.00.05'],
#  ['правовые', 'основы', 'внешнеторговой', 'деятельности'],
#  ['отсутствует'],
#  ['полуденский', 'михаил', 'петрович', 'собрание,', 'xviii-xix', 'в.'],
#  ['разработка',
#   'методов',
#   'выявления',
#   'опасных',
#   'сближений',
#   'космического',
#   'аппарата',
#   'с',
#   'наблюдаемыми',
#   'объектами',
#   'и',
#   'способов',
#   'уклонения',
#   'от',
#   'столкновений',
#   'на',
#   'фазирующей',
#   'орбите',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'технических',
#   'наук',
#   '05.07.09'],
#  ['педагогические',
#   'условия',
#   'профессиональной',
#   'подготовки',
#   'студентов',
#   'по',
#   'направлению',
#   '"туризм"',
#   'с',
#   'использованием',
#   'базовой',
#   'профильной',
#   'информации',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.08'],
#  ['отражение',
#   'корпоративной',
#   'культуры',
#   'вуза',
#   'в',
#   'имиджевом',
#   'дискурсе',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'филологических',
#   'наук',
#   '10.02.19'],
#  ['агротехнические',
#   'и',
#   'фитоценотические',
#   'методы',
#   'борьбы',
#   'с',
#   'горчаком',
#   'ползучим',
#   'в',
#   'паровом',
#   'звене',
#   'севооборота',
#   'на',
#   'каштановых',
#   'почвах',
#   'волго-донского',
#   'междуречья',
#   'диссертация',
#   '..',
#   'кандидата',
#   'сельскохозяйственных',
#   'наук',
#   '06.01.01'],
#  ['метод',
#   'декомпозиции',
#   'распределенных',
#   'сервисных',
#   'систем',
#   'с',
#   'использованием',
#   'сетей',
#   'петри',
#   'диссертация',
#   '..',
#   'кандидата',
#   'физико-математических',
#   'наук',
#   '05.13.11'],
#  ['уклонение',
#   'от',
#   'уплаты',
#   'налогов',
#   'основы',
#   'криминалистической',
#   'характеристики'],
#  ['развитие',
#   'финансового',
#   'анализа',
#   'конкурентоспособности',
#   'коммерческой',
#   'организации',
#   'диссертация',
#   '..',
#   'кандидата',
#   'экономических',
#   'наук',
#   '08.00.12'],
#  ['отсутствует'],
#  ['поэтика', 'костюма', 'в', 'прозе', 'а.', 'п.', 'чехова', 'монография'],
#  ['модели',
#   'процессов',
#   'функционирования',
#   'корпоративных',
#   'центров',
#   'обработки',
#   'данных',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'технических',
#   'наук',
#   '05.13.01'],
#  ['материалы',
#   'всероссийской',
#   'научно-практической',
#   'конференции',
#   '«эффективность',
#   'личности,',
#   'группы',
#   'и',
#   'организации',
#   'проблемы,',
#   'достижения',
#   'и',
#   'перспективы»',
#   '21-22',
#   'апреля',
#   '2017',
#   'г.,',
#   'г.',
#   'ростов-на-дону,',
#   'южный',
#   'федеральный',
#   'университет,',
#   'г.',
#   'курск,',
#   'курский',
#   'государственный',
#   'университет'],
#  ['толкование',
#   'на',
#   'первое',
#   'послание',
#   'апостола',
#   'павла',
#   'к',
#   'коринфянам',
#   'рукопись',
#   'копии',
#   'писем',
#   'феофилакта',
#   'горского',
#   'к',
#   'вел.',
#   'князю',
#   'павлу',
#   'петровичу',
#   'за',
#   '1777-1787',
#   'гг.',
#   'и',
#   'екатерине',
#   'ii',
#   'и',
#   'ответ',
#   'павла'],
#  ['философия',
#   'символа',
#   'в',
#   'творчестве',
#   'п.',
#   'а.',
#   'флоренского',
#   'диссертация',
#   '..',
#   'кандидата',
#   'философских',
#   'наук',
#   '09.00.03'],
#  ['рубашки',
#   'форменные',
#   'женские.',
#   'технические',
#   'условия',
#   '=',
#   "women''s",
#   'uniform',
#   'shirts.',
#   'specifications',
#   'государственный',
#   'стандарт',
#   'cоюза',
#   'сср',
#   'издание',
#   'официальное',
#   'утвержден',
#   'и',
#   'введен',
#   'в',
#   'действие',
#   'постановлением',
#   'государственного',
#   'комитета',
#   'ссср',
#   'по',
#   'стандартам',
#   'от',
#   '25.09.87',
#   '№',
#   '3683',
#   'введен',
#   'впервые',
#   'введен',
#   '01.01.89'],
#  ['отсутствует'],
#  ['русская',
#   'графика',
#   'начала',
#   'xx',
#   'века',
#   'очерки',
#   'истории',
#   'и',
#   'теории'],
#  ['психодидактические',
#   'условия',
#   'развития',
#   'у',
#   'подростков',
#   'понимания',
#   'лирической',
#   'поэзии',
#   'диссертация',
#   '..',
#   'кандидата',
#   'психологических',
#   'наук',
#   '19.00.07'],
#  ['отсутствует'],
#  ['формирование',
#   'общеинженерной',
#   'компетентности',
#   'курсантов',
#   'военного',
#   'вуза',
#   'в',
#   'процессе',
#   'графической',
#   'подготовки',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.08'],
#  ['иноязычная',
#   'лексика',
#   'современного',
#   'немецкого',
#   'языка',
#   '(аспекты',
#   'культурной',
#   'интеграции)',
#   'монография'],
#  ['педагогические',
#   'условия',
#   'развития',
#   'музыкальных',
#   'способностей',
#   'старших',
#   'дошкольников',
#   'в',
#   'музыкально-театрализованной',
#   'деятельности',
#   'диссертация',
#   '..',
#   'кандидата',
#   'педагогических',
#   'наук',
#   '13.00.01'],
#  ['щелочная',
#   'автоклавная',
#   'технология',
#   'вскрытия',
#   'монацитового',
#   'концентрата',
#   'автореферат',
#   'дис..',
#   'кандидата',
#   'химических',
#   'наук',
#   '05.17.02'],
#  ['сравнительная', 'педагогика', 'конспект', 'лекций'],
#  ['злоупотребление',
#   'должностными',
#   'полномочиями',
#   'уголовно-правовой',
#   'и',
#   'криминологический',
#   'аспекты',
#   'диссертация',
#   '..',
#   'кандидата',
#   'юридических',
#   'наук',
#   '12.00.08'],
#  ...]

# %%
bm25 = BM25Okapi(tokenized_corpus)

# %%
def conv_BM25(x):
    x = x.strip()
    x = x.lower()
    x = x.replace(':','')
    x = x.replace('/','')
    return x.split()

# %%
def conv_BM25_get_scores(x):
    x = conv_BM25(x)
    return bm25.get_scores(x)

# %%
title = "методы конечных элементов"
tokenized_title = conv_BM25(title)
title_scores = bm25.get_scores(tokenized_title)
title_scores
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
items['BM25_code'] = items['title'].apply(conv_BM25_get_scores)

# %%
items.to_hdf("./items.h5") # Сохранить

# %%
items = pd.read_hdf("./items.h5") # Считать

# %%
bm25.get_top_n(tokenized_title, corpus, n=10)
# Out:
# ['методы конечных элементов',
#  'применение метода конечных элементов',
#  'теория метода конечных элементов',
#  'метод конечных элементов  учебное пособие',
#  'расчеты машиностроительных конструкций методом конечных элементов  справочник',
#  'лекции по методу конечных элементов  учебное пособие',
#  'метод конечных элементов в технике  пер. с англ.',
#  'решение уравнения переноса методом конечных элементов на неструктурированных треугольных сетках',
#  'метод конечных элементов для решения уравнения переноса на неструктурированных тетраэдральных сетках',
#  'метод конечных элементов в задачах строительной и непрерывной механики  пер. с англ.']

# %%
items['BM25_code'] = items['title'].apply(conv_BM25, axis=1)
